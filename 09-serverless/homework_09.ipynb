# %% [markdown]
# ## Serverless
#
# tensorflow lite

# %%
! pip install tensorflow
# Out:
# ...
#      ---------------------------------------- 0.0/48.7 kB ? eta -:--:--
#      ---------------------------------------- 48.7/48.7 kB 1.2 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/390.3 MB ? eta -:--:--
#    ---------------------------------------- 0.1/390.3 MB 1.7 MB/s eta 0:03:44
#    ---------------------------------------- 0.2/390.3 MB 1.9 MB/s eta 0:03:31
#    ---------------------------------------- 0.3/390.3 MB 2.0 MB/s eta 0:03:19
#    ---------------------------------------- 0.4/390.3 MB 2.0 MB/s eta 0:03:14
#    ---------------------------------------- 0.4/390.3 MB 2.0 MB/s eta 0:03:15
#    ---------------------------------------- 0.5/390.3 MB 1.8 MB/s eta 0:03:31
#    ---------------------------------------- 0.6/390.3 MB 1.9 MB/s eta 0:03:29
#    ---------------------------------------- 0.6/390.3 MB 1.8 MB/s eta 0:03:41
#    ---------------------------------------- 0.7/390.3 MB 1.8 MB/s eta 0:03:36
# ...

# %%
# %pip install wget
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
! wget https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/model_2024_hairstyle.keras -O clothing-model.h5
# Out:
# 'wget' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# Install required libraries
# !pip install requests
# Import necessary libraries
import requests

# %%
import os

# Download the file
url = "https://github.com/alexeygrigorev/large-datasets/releases/download/hairstyle/model_2024_hairstyle.keras"
response = requests.get(url)
file_path = "clothing-model.h5"

# Save the file
with open(file_path, "wb") as file:
    file.write(response.content)

# Verify the file size to ensure it is downloaded correctly
if os.path.getsize(file_path) > 0:
    print("File downloaded successfully.")
else:
    print("Failed to download the file.")
# Out:
# File downloaded successfully.

# %%
import tensorflow as tf
from tensorflow import keras
tf.__version__
# Out:
# '2.18.0'

# %%
try:
    model = keras.models.load_model(file_path)
    print("Model loaded successfully.")
except OSError as e:
    print(f"Error loading model: {e}")
# Out:
# Error loading model: Unable to open file (file signature not found)
